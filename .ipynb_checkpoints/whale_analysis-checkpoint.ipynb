# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
#created a repo on git hub 
#cloned the repo locally 
#first commit and push

# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# reading the files from resources 
l_hist = pd.read_csv('l_historical.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)
otex_hist = pd.read_csv('otex_historical.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)
shop_hist = pd.read_csv('shop_historical.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Reading whale returns and index it to date 
whale_r = pd.read_csv('whale_returns.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)

# %%
# verify data and indexing 
whale_r.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls used to check if the dataframe has null
whale_r.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls - Dropped to clean the data 
# used inplace to store action permanently
whale_r.dropna(inplace = True)

# %%
whale_r.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns indexed it to date 
algo_r = pd.read_csv('algo_returns.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)

# %%
# Count nulls
algo_r.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls - Dropped to clean the data 
# used inplace to store action permanently
algo_r.dropna(inplace = True)
# verifying data frame and indexing
algo_r.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx = pd.read_csv('sp_tsx_history.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)

# %%
# Check Data Types
sp_tsx.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types - removed $ sign and , so it can changed to a float
sp_tsx['Close'] =sp_tsx['Close'].str.replace('$','', regex = True)
sp_tsx['Close'] = sp_tsx['Close'].str.replace(',','', regex = True)
#sp_tsx['Close'] = pd.to_numeric(sp_tsx['Close'])

# %%
# changed close values to float for further calculating the percent change
sp_tsx[['Close']] = sp_tsx[['Close']].astype(float)
sp_tsx.dtypes
# Calculate Daily Returns
sp_tsx['pct_chng'] = sp_tsx['Close'].pct_change()

# %%
# check for null values 
#sp_tsx.isna().sum()
# Drop nulls
sp_tsx.dropna(inplace = True)
#verify if number of records changed to confirm null was dropped 
#sp_tsx

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_2 = sp_tsx.rename(columns={"pct_chng": "S&P TSX"})
sp_tsx_2.drop('Close', 1, inplace = True)
# Out:
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\309689951.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   sp_tsx_2.drop('Close', 1, inplace = True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combine_data = [whale_r,algo_r,sp_tsx_2]
combine_data_2 = pd.concat(combine_data, axis ="columns", join="inner")
combine_data_2
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
whale_r.plot(legend = True)
algo_r.plot(legend = True)
sp_tsx_2.plot(legend = True)
#calculate and plot for the remaining portfolios 
portfolio = [l_hist, otex_hist, shop_hist]
for value in portfolio:
    value['pct_chng'] = value['Close'].pct_change()
    value.dropna(inplace = True)
    value.drop('Close', 1, inplace = True)
l_hist_2 = l_hist.rename(columns={"pct_chng": "L Historical"})
l_hist_2.plot(legend = True)
otex_hist_2 = otex_hist.rename(columns={"pct_chng": "OTEX Historical"})
otex_hist_2.plot(legend = True)
shop_hist_2 = shop_hist.rename(columns={"pct_chng": "SHOP Historical"})
shop_hist_2.plot(legend = True)
#combine all the portfolios to calculate comulative returns in the next step
mast_data = [whale_r,algo_r,sp_tsx_2,l_hist_2,otex_hist_2,shop_hist_2]
mast_data_2 = pd.concat(mast_data, axis ="columns", join="inner")
# Out:
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\2535097745.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   value.drop('Close', 1, inplace = True)
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\2535097745.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   value.drop('Close', 1, inplace = True)
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\2535097745.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   value.drop('Close', 1, inplace = True)

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
mast_data_2 = mast_data_2.drop('Symbol',1)

# Calculate cumulative returns of all portfolios
cum_return = (mast_data_2+1).cumprod()
# Plot cumulative returns
cum_return.plot(figsize=(15, 10))
# Out:
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\2603511552.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   mast_data_2 = mast_data_2.drop('Symbol',1)
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
#mast_data = [whale_r,algo_r,sp_tsx_2,l_hist_2,otex_hist_2,shop_hist_2]
mast_data_2.boxplot(figsize =(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
print(whale_r.std())
print(algo_r.std())
print(l_hist_2.std())
print(otex_hist_2.std())
print(shop_hist_2.std())
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64
# L Historical    0.009598
# dtype: float64
# OTEX Historical    0.013552
# dtype: float64
# SHOP Historical    0.030786
# dtype: float64
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\2573888361.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(l_hist_2.std())
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\2573888361.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
daily_std = sp_tsx_2['S&P TSX'].std()
print(daily_std)
# Determine which portfolios are riskier than the S&P TSX 60
# Out:
# 0.006637362556692504

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annual_std_dev = mast_data_2.std()*252**.5
annual_std_dev
# Out:
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# Algo 1                         0.120028
# Algo 2                         0.137664
# S&P TSX                        0.099121
# L Historical                   0.162907
# OTEX Historical                0.225703
# SHOP Historical                0.504079
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
#mast_data = [whale_r,algo_r,sp_tsx_2,l_hist_2,otex_hist_2,shop_hist_2]
whale_r_1 = whale_r.rolling(window =21).std()
algo_r_1 = algo_r.rolling(window =21).std()
l_hist_1 = l_hist_2.rolling(window =21).std()
otex_hist_1 = otex_hist_2.rolling(window =21).std()
shop_hist_1 = shop_hist_2.rolling(window =21).std()
# Plot the rolling standard deviation
whale_r_1.plot()
algo_r_1.plot()
l_hist_1.plot()
otex_hist_1.plot()
shop_hist_1.plot()
# Out:
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\3515445727.py:5: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Symbol'], dtype='object')
#   l_hist_1 = l_hist_2.rolling(window =21).std()
# C:\Users\deves\AppData\Local\Temp\ipykernel_22488\3515445727.py:6: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Symbol'], dtype='object')
#   otex_hist_1 = otex_hist_2.rolling(window =21).std()
# ...

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

mast_data_2.corr()

# Display de correlation matrix

import seaborn as sns
sns.heatmap(mast_data_2.corr(), vmin = -1, vmax = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
cov_w = whale_r['SOROS FUND MANAGEMENT LLC'].cov(whale_r['SOROS FUND MANAGEMENT LLC'])
# Calculate variance of S&P TSX
sp_var = sp_tsx_2['S&P TSX'].var()
# Computing beta
beta = cov_w /sp_var

# Plot beta trend
rolling_covariance = whale_r['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(whale_r['SOROS FUND MANAGEMENT LLC'])
rolling_variance = sp_tsx_2['S&P TSX'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance 
rolling_beta.plot(figsize=(20,10), title = 'Rolling 60 Days Beta')
# Out:
# <AxesSubplot:title={'center':'Rolling 60 Days Beta'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
#mast_data_2.ewm(halflife='21 days', times = mast_data_2['Date']).std()

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (mast_data_2.mean() * 252) / (mast_data_2.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC     -0.088196
# PAULSON & CO.INC.             -0.396282
# TIGER GLOBAL MANAGEMENT LLC   -1.391612
# BERKSHIRE HATHAWAY INC         0.195907
# Algo 1                         1.901461
# Algo 2                         0.021394
# S&P TSX                        0.034651
# L Historical                   0.532599
# OTEX Historical                0.762776
# SHOP Historical                1.575294
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# #### Algo 1 will out perform both S&P TSX 60 and the Whales portfolios

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
custom_data = pd.read_csv('google_finance_data.csv.csv', index_col='Date', parse_dates=True, infer_datetime_format=True)
aapl = custom_data['AAPL']
# Out:
# Date
# 2021-03-19    119.99
# 2021-03-22    123.39
# 2021-03-23    122.54
# 2021-03-24    120.09
# 2021-03-25    120.59
#                ...
# 2022-03-14    150.62
# 2022-03-15    155.09
# 2022-03-16    159.59
# 2022-03-17    160.62
# 2022-03-18    163.98
# Name: AAPL, Length: 253, dtype: float64

# %%
# Reading data from 2nd stock

# %%
# Reading data from 3rd stock

# %%
# Combine all stocks in a single DataFrame

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns

# Drop NAs

# Display sample data

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

# Display sample data

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

# %%
# Visualize the sharpe ratios as a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
